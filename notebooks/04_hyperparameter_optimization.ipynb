# %% [markdown]
# # Fase 6: Hyperparameter Optimization
#
# Optimización exhaustiva de hiperparámetros.
#
# ## Requerimientos:
# - GridSearchCV en 2-3 modelos
# - RandomizedSearchCV en 2-3 modelos
# - Análisis de impacto
# - Documentación del proceso

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys

sys.path.append('../src')
from hyperparameter_tuning import *

np.random.seed(42)
sns.set_style('whitegrid')

# %% [markdown]
# ## 1. GridSearchCV
#
# Búsqueda exhaustiva de parámetros

# %%
# Ejemplo: Optimizar Random Forest
# param_grid = {
#     'model__n_estimators': [50, 100, 200],
#     'model__max_depth': [5, 10, 15, None],
#     'model__min_samples_split': [2, 5, 10],
#     'model__min_samples_leaf': [1, 2, 4]
# }
#
# grid_search = grid_search_optimization(
#     model=models['Random Forest'],
#     X_train=X_train,
#     y_train=y_train,
#     param_grid=param_grid,
#     cv=5,
#     scoring='accuracy'
# )

# %% [markdown]
# ## 2. RandomizedSearchCV
#
# Búsqueda aleatoria (más rápida)

# %%
# Ejemplo: Optimizar SVM
# param_dist = {
#     'model__C': [0.1, 1, 10, 100],
#     'model__kernel': ['linear', 'rbf', 'poly']
# }
#
# random_search = random_search_optimization(
#     model=models['SVM'],
#     X_train=X_train,
#     y_train=y_train,
#     param_distributions=param_dist,
#     n_iter=20,
#     cv=5,
#     scoring='accuracy'
# )

# %% [markdown]
# ## 3. Mejores Parámetros

# %%
# Obtener mejores parámetros
# best_params_rf = get_best_params(grid_search)
# best_score_rf = get_best_score(grid_search)
# print(f"Best params (Random Forest): {best_params_rf}")
# print(f"Best score (Random Forest): {best_score_rf}")

# %% [markdown]
# ## 4. Comparación Original vs Optimizado

# %%
# Crear reportes de optimización
# report_rf = create_optimization_report(
#     original_score=original_rf_score,
#     optimized_score=best_score_rf,
#     original_params=original_rf_params,
#     optimized_params=best_params_rf
# )

# %% [markdown]
# ## 5. Visualización del Impacto

# %%
# Graficar impacto de optimización
# plot_optimization_impact(reports_dict, output_path='../results/plots/optimization_impact.png')

# %% [markdown]
# ## 6. Reporte Final

# %%
# Guardar reporte de optimización
# save_optimization_report(reports_dict, '../results/reports/optimization_report.csv')
