# %% [markdown]
# # Fase 5: Model Evaluation
#
# Evaluación comparativa exhaustiva de todos los modelos.
#
# ## Requerimientos:
# - Cross-validation robusta (k-fold)
# - TODAS las métricas relevantes
# - Tabla comparativa
# - Visualizaciones avanzadas (ROC, confusion matrix, etc.)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
from sklearn.model_selection import cross_validate

sys.path.append('../src')
from model_evaluation import *

np.random.seed(42)
sns.set_style('whitegrid')

# %% [markdown]
# ## 1. Cross-Validation Robusta

# %%
# Implementar k-fold cross-validation
# A rellenar en el trabajo iterativo

# %% [markdown]
# ## 2. Cálculo de Métricas
#
# Para clasificación:
# - Accuracy
# - Precision
# - Recall
# - F1-Score
# - AUC-ROC
# - Confusion Matrix

# %%
# Calcular métricas para cada modelo
# A rellenar en el trabajo iterativo

# %% [markdown]
# ## 3. Tabla Comparativa

# %%
# Crear tabla comparativa
# A rellenar en el trabajo iterativo

# %%
# Guardar tabla de métricas
# save_metrics_table(comparison_df, '../results/metrics/model_metrics.csv')

# %% [markdown]
# ## 4. Visualizaciones

# %%
# Gráfico comparativo de métricas
# A rellenar en el trabajo iterativo

# %%
# Matrices de confusión por modelo
# A rellenar en el trabajo iterativo

# %% [markdown]
# ## 5. Análisis Comparativo

# %%
# Análisis de resultados
# - ¿Cuál es el mejor modelo?
# - Trade-offs entre métricas
# - Interpretación de resultados
