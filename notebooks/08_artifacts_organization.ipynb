# %% [markdown]
# # FASE 8: Artifacts Organization

# %%
import os
paths = ['../models/trained_models/', '../results/metrics/', '../results/reports/', '../results/plots/']
for p in paths:
    if os.path.exists(p):
        print(f'Checking {p}: {os.listdir(p)}')
