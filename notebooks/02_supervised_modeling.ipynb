# %% [markdown]
# # Fase 3 & 4: Supervised & Unsupervised Modeling
#
# Este notebook implementa:
# - Más de 4 modelos supervisados (clasificación/regresión)
# - Clustering (K-Means, Hierarchical, DBSCAN)
# - Reducción de dimensionalidad (PCA)
#
# ## Requerimientos:
# - Pipelines de Scikit-learn para cada modelo
# - Más de 4 modelos diferentes
# - Justificación técnica documentada

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

# Importar funciones del módulo
sys.path.append('../src')
from data_preprocessing import *
from model_training import *

# Configuración
sns.set_style('whitegrid')
np.random.seed(42)
RANDOM_STATE = 42

# %% [markdown]
# ## 1. Preparación de Datos

# %%
# Cargar datos
# A rellenar en el trabajo iterativo

# %% [markdown]
# ## 2. Modelos Supervisados
#
# Implementar 5+ modelos con justificación

# %%
# Crear modelos
models = {}

# 1. Logistic Regression
# Justificación: Modelo lineal simple, interpretable, excelente baseline
models['Logistic Regression'] = create_logistic_regression(RANDOM_STATE)

# 2. Decision Tree
# Justificación: Capta relaciones no lineales, fácil interpretación
models['Decision Tree'] = create_decision_tree(RANDOM_STATE)

# 3. Random Forest
# Justificación: Ensemble de árboles, mejor generalización, reduce overfitting
models['Random Forest'] = create_random_forest(RANDOM_STATE)

# 4. SVM
# Justificación: Excelente para datos de alta dimensión, margen máximo
models['SVM'] = create_svm(RANDOM_STATE)

# 5. KNN
# Justificación: Captura patrones locales, sin parámetros a entrenar
models['KNN'] = create_knn(n_neighbors=5)

# 6. Gradient Boosting
# Justificación: Estado del arte, construye modelos secuencialmente
models['Gradient Boosting'] = create_gradient_boosting(RANDOM_STATE)

print("Modelos creados:")
for name in models.keys():
    print(f"  - {name}")

# %%
# Entrenar modelos
trained_models = {}

# A rellenar en el trabajo iterativo con datos preprocesados
# for name, model in models.items():
#     trained_models[name] = train_model(model, X_train, y_train)

# %%
# Guardar modelos entrenados
# for name, model in trained_models.items():
#     save_model(model, f'../models/trained_models/{name.lower().replace(" ", "_")}.joblib')

# %% [markdown]
# ## 3. Modelos No Supervisados
#
# ### 3.1 Clustering

# %%
# Clustering (K-Means, Hierarchical, DBSCAN)
# A rellenar en el trabajo iterativo

# %% [markdown]
# ### 3.2 Reducción de Dimensionalidad

# %%
# PCA y t-SNE
# A rellenar en el trabajo iterativo
